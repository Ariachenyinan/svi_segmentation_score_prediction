# %%
import pandas as pd 
import numpy as np
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
svi_label = pd.read_excel('F:/1-TechArt材料/1阶段三/建成环境二级因子_all.xlsx')
svi_label
# Out:
#            img      road  sidewalk  building      wall     fence      pole
# 0    A_001.jpg  0.022920  0.054115  0.279379  0.005092  0.028589  0.000749  \
# 1    A_005.jpg  0.045888  0.037875  0.362758  0.002119  0.022121  0.002115
# 2    A_009.jpg  0.056443  0.052737  0.370177  0.000818  0.017477  0.000107
# 3    A_013.jpg  0.047194  0.011503  0.142797  0.029945  0.131668  0.000041
# 4    A_017.jpg  0.112390  0.012864  0.139911  0.022371  0.010343  0.001495
# ..         ...       ...       ...       ...       ...       ...       ...
# 259  Z_017.jpg  0.226954  0.031340  0.511351  0.000245  0.027360  0.013223
# 260  Z_021.jpg  0.136848  0.044366  0.435465  0.000000  0.000000  0.011575
# 261  Z_025.jpg  0.162991  0.012236  0.283684  0.000000  0.000000  0.016587
# 262  Z_029.jpg  0.145428  0.060891  0.350237  0.000000  0.004606  0.000012
# 263  Z_031.jpg  0.160496  0.007356  0.521458  0.000395  0.000094  0.007028
#
# ...

# %%
svi_des = svi_label.describe().T
svi_des
# Out:
#                   count      mean       std       min       25%       50%
# road              264.0  0.135990  0.067937  0.003893  0.088723  0.123461  \
# sidewalk          264.0  0.025916  0.028556  0.000000  0.005328  0.015590
# building          264.0  0.316565  0.188062  0.001634  0.179193  0.311149
# wall              264.0  0.010979  0.036102  0.000000  0.000000  0.001030
# fence             264.0  0.028304  0.048370  0.000000  0.000436  0.007737
# pole              264.0  0.009152  0.013665  0.000000  0.001219  0.004905
# traffic light     264.0  0.000219  0.000659  0.000000  0.000000  0.000005
# traffic sign      264.0  0.002453  0.005276  0.000000  0.000137  0.000598
# nature            264.0  0.342115  0.217416  0.000190  0.192734  0.325743
# sky               264.0  0.024920  0.037315  0.000000  0.000327  0.005245
# person            264.0  0.019832  0.030824  0.000000  0.002540  0.008529
# rider             264.0  0.005049  0.010835  0.000000  0.000066  0.001457
# ...

# %%
df = svi_des.loc[:,['count','mean','std','min','max']]
df
# Out:
#                   count      mean       std       min       max
# road              264.0  0.135990  0.067937  0.003893  0.444435
# sidewalk          264.0  0.025916  0.028556  0.000000  0.174593
# building          264.0  0.316565  0.188062  0.001634  0.769943
# wall              264.0  0.010979  0.036102  0.000000  0.362494
# fence             264.0  0.028304  0.048370  0.000000  0.307211
# pole              264.0  0.009152  0.013665  0.000000  0.117497
# traffic light     264.0  0.000219  0.000659  0.000000  0.006116
# traffic sign      264.0  0.002453  0.005276  0.000000  0.044022
# nature            264.0  0.342115  0.217416  0.000190  0.875417
# sky               264.0  0.024920  0.037315  0.000000  0.252200
# person            264.0  0.019832  0.030824  0.000000  0.237457
# rider             264.0  0.005049  0.010835  0.000000  0.111698
# vehicle           264.0  0.048368  0.067358  0.000000  0.333991
# motorcycle        264.0  0.017105  0.028716  0.000000  0.177899
# ...

# %%
df2 =df.sort_values(by=['mean','std'],ascending=False)
df2
# Out:
#                   count      mean       std       min       max
# nature            264.0  0.342115  0.217416  0.000190  0.875417
# building          264.0  0.316565  0.188062  0.001634  0.769943
# road              264.0  0.135990  0.067937  0.003893  0.444435
# vehicle           264.0  0.048368  0.067358  0.000000  0.333991
# fence             264.0  0.028304  0.048370  0.000000  0.307211
# sidewalk          264.0  0.025916  0.028556  0.000000  0.174593
# sky               264.0  0.024920  0.037315  0.000000  0.252200
# person            264.0  0.019832  0.030824  0.000000  0.237457
# motorcycle        264.0  0.017105  0.028716  0.000000  0.177899
# bicycle           264.0  0.012568  0.022202  0.000000  0.135551
# wall              264.0  0.010979  0.036102  0.000000  0.362494
# pole              264.0  0.009152  0.013665  0.000000  0.117497
# sign              264.0  0.007908  0.016076  0.000000  0.118670
# street item       264.0  0.006379  0.014738  0.000000  0.121912
# ...

# %%
df2.to_csv('df2.csv')
